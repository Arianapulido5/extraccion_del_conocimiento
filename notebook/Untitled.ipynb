# %%
#Datos Sintéticos
#Utilización de la libreria FAKER
#Autor: Ariana Belinda Pulido Solano

# %%
import pandas as pd
import numpy as np
import random

# %%
#Importamos la libreria Faker
from faker import Faker

# %%
pip install faker
# Out:
# Requirement already satisfied: faker in C:\Users\arian\anaconda3\envs\Ariana\Lib\site-packages (40.20.0)
# Requirement already satisfied: tzdata in C:\Users\arian\anaconda3\envs\Ariana\Lib\site-packages (from faker) (2026.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Creamis una instancia de Faker
fake = Faker("es_MX")

# %%
#Generamos datos sintéticos o datos falsos
datos = []
for i in range(100):
    datos.append(
        {
            "id_usuario" : i+1,
            "nombre": fake.name(),
            "correo" : fake.email(),
            "edad" : random.randint(18,65),
            "seguidores" : random.randint(50,5000),
            "plataforma" :random.choice(["TikTok","Instagram","YouTube"])
        }
    )

# %%
dfInfluencer = pd.DataFrame(datos)

# %%
dfInfluencer
# Out:
#     id_usuario                             nombre  \
# 0            1             Adán Abraham Mondragón
# 1            2              Srita. Marcela Chávez
# 2            3               Juan Valadez Sánchez
# 3            4      Clemente Eric Barrera Delgado
# 4            5          Jorge Julio César Acevedo
# ..         ...                                ...
# 95          96  Sandra Concepción Cornejo Partida
# 96          97  Diego Jorge Luis Carreón Saavedra
# 97          98               Darío Mendoza Patiño
# 98          99               Sandra Carla Collazo
# 99         100              Lic. Pascual Carrillo
#
#                           correo  edad  seguidores plataforma
# 0      catalinaochoa@example.org    61        2479  Instagram
# 1     cristiandavila@example.org    32        4477  Instagram
# 2           yvelasco@example.net    30        2546  Instagram
# 3          dolores66@example.org    32        3287  Instagram
# 4         ramonsonia@example.com    38        1406     TikTok
# ..                           ...   ...         ...        ...
# 95        carolina39@example.org    31         861    YouTube
# 96     murilloamelia@example.org    58         946     TikTok
# 97  montenegroalvaro@example.net    24         922     TikTok
# 98            furena@example.net    51        4633  Instagram
# 99      vde-la-torre@example.net    49         720  Instagram
#
# [100 rows x 6 columns]

# %%
dfInfluencer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_usuario  100 non-null    int64
#  1   nombre      100 non-null    str
#  2   correo      100 non-null    str
#  3   edad        100 non-null    int64
#  4   seguidores  100 non-null    int64
#  5   plataforma  100 non-null    str
# dtypes: int64(3), str(3)
# memory usage: 4.8 KB

# %%
dfInfluencer.describe()
# Out:
#        id_usuario        edad   seguidores
# count  100.000000  100.000000   100.000000
# mean    50.500000   39.860000  2520.760000
# std     29.011492   14.141436  1456.261119
# min      1.000000   18.000000   249.000000
# 25%     25.750000   26.750000  1237.250000
# 50%     50.500000   39.000000  2390.500000
# 75%     75.250000   52.000000  4076.750000
# max    100.000000   65.000000  4904.000000

# %%
dfInfluencer.describe(include="all")
# Out:
#         id_usuario                  nombre                     correo  \
# count   100.000000                     100                        100
# unique         NaN                     100                        100
# top            NaN  Adán Abraham Mondragón  catalinaochoa@example.org
# freq           NaN                       1                          1
# mean     50.500000                     NaN                        NaN
# std      29.011492                     NaN                        NaN
# min       1.000000                     NaN                        NaN
# 25%      25.750000                     NaN                        NaN
# 50%      50.500000                     NaN                        NaN
# 75%      75.250000                     NaN                        NaN
# max     100.000000                     NaN                        NaN
#
#               edad   seguidores plataforma
# count   100.000000   100.000000        100
# unique         NaN          NaN          3
# top            NaN          NaN  Instagram
# freq           NaN          NaN         37
# mean     39.860000  2520.760000        NaN
# std      14.141436  1456.261119        NaN
# min      18.000000   249.000000        NaN
# 25%      26.750000  1237.250000        NaN
# 50%      39.000000  2390.500000        NaN
# 75%      52.000000  4076.750000        NaN
# max      65.000000  4904.000000        NaN

# %%
#Graficar
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Graficamos como se generan las edades
plt.figure(figsize = (8,4))
sns.histplot(dfInfluencer["edad"], bins=10)
plt.title("Distribución de edades")
plt.show()

# %%
#Graficamos la cantidad de usuarios por plataforma
plt.figure(figsize = (8.4))
sns.countplot(x="plataforma"), data = dfInfluencer
plt.title("Cantidad de usuarios por plataforma")
plt.show()
# Out:
#   Cell In[40], line 3
#     sns.countplot(x="plataforma"), data = dfInfluencer
#                                    ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
